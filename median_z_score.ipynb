# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaftha/SOURCE-SELECTION-IN-MULTI-SOURCE-CROSS-PROJECT-DEFECT-PREDICTION/blob/main/median_z_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Collecting Data

# %%
# Pengumpulan data set
import pandas as pd
# Pemanggilan dataset ant-1.7
df1 = pd.read_csv('ant-1.7.csv', index_col='name')
# Pemanggilan dataset camel-1.6
df2 = pd.read_csv('camel-1.6.csv', index_col='name')
# Pemanggilan dataset ivy-2.0
df3 = pd.read_csv('ivy-2.0.csv', index_col='name')
# Pemanggilan dataset jedit-4.3
df4 = pd.read_csv('jedit-4.3.csv', index_col='name')
# Pemanggilan dataset Log4j-1.2
df5 = pd.read_csv('log4j-1.2.csv', index_col='name')
# Pemanggilan dataset lucene-2.4
df6 = pd.read_csv('lucene-2.4.csv', index_col='name')
# Pemanggilan dataset poi-3.0
df7 = pd.read_csv('poi-3.0.csv', index_col='name')
# Pemanggilan dataset synapse-1.2
df8 = pd.read_csv('synapse-1.2.csv', index_col='name')
# Pemanggilan dataset velocity-1.6
df9 = pd.read_csv('velocity-1.6.csv', index_col='name')
# Pemanggilan dataset xalan-2.7
df10 = pd.read_csv('xalan-2.7.csv', index_col='name')
# Pemanggilan dataset xerces-1.4.4
df11 = pd.read_csv('xerces-1.4.4.csv', index_col='name')

# menampilkan dataset 10 data teratas
df1.head(10)
# Out:
#                                                     wmc  dit  noc  cbo  rfc  \
# name
# org.apache.tools.ant.taskdefs.rmic.RmicAdapterF...    3    1    0   10   18
# org.apache.tools.ant.taskdefs.optional.perforce...    5    2    0    4   13
# org.apache.tools.ant.taskdefs.optional.junit.Ou...    1    2    0    1    3
# org.apache.tools.ant.taskdefs.optional.perforce...    8    1    9   13   20
# org.apache.tools.ant.taskdefs.WaitFor                 9    3    0    5   26
# org.apache.tools.ant.taskdefs.optional.depend.c...    3    2    5    7    4
# org.apache.tools.zip.AsiExtraField                   20    1    0    4   40
# org.apache.tools.ant.types.resources.selectors....   13    1    0    7   28
# org.apache.tools.ant.util.facade.FacadeTaskHelper     9    1    0    5   19
# org.apache.tools.ant.types.selectors.DepthSelector    7    5    0    9   25
#
#                                                     lcom  ca  ce  npm  \
# name
# ...

# %% [markdown]
# ##prepocessing

# %%
#pengecekan pada dataset yang memiliki nilai missing value
df1.isnull().sum()
df2.isnull().sum()
df3.isnull().sum()
df4.isnull().sum()
df5.isnull().sum()
df6.isnull().sum()
df7.isnull().sum()
df8.isnull().sum()
df9.isnull().sum()
df10.isnull().sum()
df11.isnull().sum()
# Out:
# wmc       0
# dit       0
# noc       0
# cbo       0
# rfc       0
# lcom      0
# ca        0
# ce        0
# npm       0
# lcom3     0
# loc       0
# dam       0
# moa       0
# mfa       0
# cam       0
# ic        0
# cbm       0
# amc       0
# max_cc    0
# avg_cc    0
# bug       0
# dtype: int64

# %%
# mengisi mising value dengan nilai rata-rata fitur
df1.fillna(df1.mean(), inplace=True)
df2.fillna(df2.mean(), inplace=True)
df3.fillna(df3.mean(), inplace=True)
df4.fillna(df4.mean(), inplace=True)
df5.fillna(df5.mean(), inplace=True)
df6.fillna(df5.mean(), inplace=True)
df7.fillna(df5.mean(), inplace=True)
df8.fillna(df5.mean(), inplace=True)
df9.fillna(df5.mean(), inplace=True)
df10.fillna(df5.mean(), inplace=True)
df11.fillna(df5.mean(), inplace=True)

# %%
df1["bug"] = df1["bug"].apply(lambda x: 1 if x >= 1 else 0)
df2["bug"] = df2["bug"].apply(lambda x: 1 if x >= 1 else 0)
df3["bug"] = df3["bug"].apply(lambda x: 1 if x >= 1 else 0)
df4["bug"] = df4["bug"].apply(lambda x: 1 if x >= 1 else 0)
df5["bug"] = df5["bug"].apply(lambda x: 1 if x >= 1 else 0)
df6["bug"] = df6["bug"].apply(lambda x: 1 if x >= 1 else 0)
df7["bug"] = df7["bug"].apply(lambda x: 1 if x >= 1 else 0)
df8["bug"] = df8["bug"].apply(lambda x: 1 if x >= 1 else 0)
df9["bug"] = df9["bug"].apply(lambda x: 1 if x >= 1 else 0)
df10["bug"] = df10["bug"].apply(lambda x: 1 if x >= 1 else 0)
df11["bug"] = df11["bug"].apply(lambda x: 1 if x >= 1 else 0)

df1.head(10)
# Out:
#                                                     wmc  dit  noc  cbo  rfc  \
# name
# org.apache.tools.ant.taskdefs.rmic.RmicAdapterF...    3    1    0   10   18
# org.apache.tools.ant.taskdefs.optional.perforce...    5    2    0    4   13
# org.apache.tools.ant.taskdefs.optional.junit.Ou...    1    2    0    1    3
# org.apache.tools.ant.taskdefs.optional.perforce...    8    1    9   13   20
# org.apache.tools.ant.taskdefs.WaitFor                 9    3    0    5   26
# org.apache.tools.ant.taskdefs.optional.depend.c...    3    2    5    7    4
# org.apache.tools.zip.AsiExtraField                   20    1    0    4   40
# org.apache.tools.ant.types.resources.selectors....   13    1    0    7   28
# org.apache.tools.ant.util.facade.FacadeTaskHelper     9    1    0    5   19
# org.apache.tools.ant.types.selectors.DepthSelector    7    5    0    9   25
#
#                                                     lcom  ca  ce  npm  \
# name
# ...

# %%
df1.bug.value_counts()
df2.bug.value_counts()
df3.bug.value_counts()
df4.bug.value_counts()
df5.bug.value_counts()
df6.bug.value_counts()
df7.bug.value_counts()
df8.bug.value_counts()
df9.bug.value_counts()
df10.bug.value_counts()
df11.bug.value_counts()
# Out:
# 1    437
# 0    151
# Name: bug, dtype: int64

# %%
df1.bug.unique()
df2.bug.unique()
df3.bug.unique()
df4.bug.unique()
df5.bug.unique()
df6.bug.unique()
df7.bug.unique()
df8.bug.unique()
df9.bug.unique()
df10.bug.unique()
df11.bug.unique()
# Out:
# array([1, 0])

# %%
feature1 = df1[['wmc','dit','noc','cbo','rfc','lcom']]
feature2 = df2[['wmc','dit','noc','cbo','rfc','lcom']]
feature3 = df3[['wmc','dit','noc','cbo','rfc','lcom']]
feature4 = df4[['wmc','dit','noc','cbo','rfc','lcom']]
feature5 = df5[['wmc','dit','noc','cbo','rfc','lcom']]
feature6 = df6[['wmc','dit','noc','cbo','rfc','lcom']]
feature7 = df7[['wmc','dit','noc','cbo','rfc','lcom']]
feature8 = df8[['wmc','dit','noc','cbo','rfc','lcom']]
feature9 = df9[['wmc','dit','noc','cbo','rfc','lcom']]
feature10 = df10[['wmc','dit','noc','cbo','rfc','lcom']]
feature11 = df11[['wmc','dit','noc','cbo','rfc','lcom']]

# %%
target1 = df1['bug']
target2 = df2['bug']
target3 = df3['bug']
target4 = df4['bug']
target5 = df5['bug']
target6 = df6['bug']
target7 = df7['bug']
target8 = df8['bug']
target9 = df9['bug']
target10 = df10['bug']
target11 = df11['bug']

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# Split the data into training and testing sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(feature1, target1, test_size=0.2, random_state=0)
X_train2, X_test2, y_train2, y_test2 = train_test_split(feature2, target2, test_size=0.2, random_state=0)
X_train3, X_test3, y_train3, y_test3 = train_test_split(feature3, target3, test_size=0.2, random_state=0)
X_train4, X_test4, y_train4, y_test4 = train_test_split(feature4, target4, test_size=0.2, random_state=0)
X_train5, X_test5, y_train5, y_test5 = train_test_split(feature5, target5, test_size=0.2, random_state=0)
X_train6, X_test6, y_train6, y_test6 = train_test_split(feature6, target6, test_size=0.2, random_state=0)
X_train7, X_test7, y_train7, y_test7 = train_test_split(feature7, target7, test_size=0.2, random_state=0)
X_train8, X_test8, y_train8, y_test8 = train_test_split(feature8, target8, test_size=0.2, random_state=0)
X_train9, X_test9, y_train9, y_test9 = train_test_split(feature9, target9, test_size=0.2, random_state=0)
X_train10, X_test10, y_train10, y_test10 = train_test_split(feature10, target10, test_size=0.2, random_state=0)
X_train11, X_test11, y_train11, y_test11 = train_test_split(feature11, target11, test_size=0.2, random_state=0)

# %%
X_train1.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test1.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train2.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test2.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train3.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test3.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train4.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test4.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train5.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test5.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train6.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test6.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train7.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test7.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train8.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test8.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train9.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test9.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train10.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test10.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train11.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test11.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train1.head(10)
# Out:
#                                                     wmc  dit  noc  cbo  rfc  \
# name
# org.apache.tools.ant.taskdefs.optional.clearcas...    5    4    0    7   27
# org.apache.tools.ant.taskdefs.optional.junit.XM...   12    3    0   11   75
# org.apache.tools.ant.taskdefs.optional.ejb.Jbos...    6    2    0    5   23
# org.apache.tools.ant.Executor                         2    1    0    4    2
# org.apache.tools.ant.taskdefs.optional.extensio...   13    3    0   10   36
# org.apache.tools.ant.types.resources.Sort             4    4    1   11   20
# org.apache.tools.ant.util.LineOrientedOutputStream    7    2    2    2   15
# org.apache.tools.ant.ProjectComponent                10    1   28   67   14
# org.apache.tools.ant.taskdefs.optional.ejb.IPla...   20    1    0    7   79
# org.apache.tools.ant.taskdefs.Copy                   45    3    2   25  157
#
#                                                     lcom
# name
# org.apache.tools.ant.taskdefs.optional.clearcas...     4
# ...

# %%
from scipy.stats import zscore

# Normalize df1 using Z-score

X_train1 = X_train1.apply(zscore)
X_train1 = pd.DataFrame(X_train1, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test1 = X_test1.apply(zscore)
X_test1 = pd.DataFrame(X_test1, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train2 = X_train2.apply(zscore)
X_train2 = pd.DataFrame(X_train2, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test2 = X_test2.apply(zscore)
X_test2 = pd.DataFrame(X_test2, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train3 = X_train3.apply(zscore)
X_train3 = pd.DataFrame(X_train3, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test3 = X_test3.apply(zscore)
X_test3 = pd.DataFrame(X_test3, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train4 = X_train4.apply(zscore)
X_train4 = pd.DataFrame(X_train4, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test4 = X_test4.apply(zscore)
X_test4 = pd.DataFrame(X_test4, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train5 = X_train5.apply(zscore)
X_train5 = pd.DataFrame(X_train5, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test5 = X_test5.apply(zscore)
X_test5 = pd.DataFrame(X_test5, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train6 = X_train6.apply(zscore)
X_train6 = pd.DataFrame(X_train6, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test6 = X_test6.apply(zscore)
X_test6 = pd.DataFrame(X_test6, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train7 = X_train7.apply(zscore)
X_train7 = pd.DataFrame(X_train7, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test7 = X_test7.apply(zscore)
X_test7 = pd.DataFrame(X_test7, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train8 = X_train8.apply(zscore)
X_train8 = pd.DataFrame(X_train8, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test8 = X_test8.apply(zscore)
X_test8 = pd.DataFrame(X_test8, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train9 = X_train9.apply(zscore)
X_train9 = pd.DataFrame(X_train9, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test9 = X_test9.apply(zscore)
X_test9 = pd.DataFrame(X_test9, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train10 = X_train10.apply(zscore)
X_train10 = pd.DataFrame(X_train10, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test10 = X_test10.apply(zscore)
X_test10 = pd.DataFrame(X_test10, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

X_train11 = X_train11.apply(zscore)
X_train11 = pd.DataFrame(X_train11, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])
X_test11 = X_test11.apply(zscore)
X_test11 = pd.DataFrame(X_test11, columns=['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom'])

print(X_train1)
# Out:
#                                                          wmc       dit  \
# name
# org.apache.tools.ant.taskdefs.optional.clearcas... -0.500540  1.062934
# org.apache.tools.ant.taskdefs.optional.junit.XM...  0.065382  0.334763
# org.apache.tools.ant.taskdefs.optional.ejb.Jbos... -0.419694 -0.393408
# org.apache.tools.ant.Executor                      -0.743078 -1.121579
# org.apache.tools.ant.taskdefs.optional.extensio...  0.146228  0.334763
# ...                                                      ...       ...
# org.apache.tools.ant.taskdefs.optional.ssh.SSHBase  0.550458  0.334763
# org.apache.tools.ant.UnknownElement                 1.601456  0.334763
# org.apache.tools.ant.taskdefs.optional.native2a... -0.581386 -1.121579
# org.apache.tools.ant.taskdefs.Jar                   1.601456  1.791106
# org.apache.tools.ant.types.selectors.FileSelector  -0.823924 -1.121579
#
#                                                          noc       cbo  \
# name
# ...

# %% [markdown]
# ##source selection (Median Z-Score)

# %%
import pandas as pd
# Hitung median data training
median_train1 = X_train1.median()
median_train2 = X_train2.median()
median_train3 = X_train3.median()
median_train4 = X_train4.median()
median_train5 = X_train5.median()
median_train6 = X_train6.median()
median_train7 = X_train7.median()
median_train8 = X_train8.median()
median_train9 = X_train9.median()
median_train10 = X_train10.median()
median_train11 = X_train11.median()

print("Median:", median_train1)
# Out:
# Median: wmc    -0.338848
# dit     0.334763
# noc    -0.155422
# cbo    -0.225224
# rfc    -0.323694
# lcom   -0.233368
# dtype: float64

# %%
import pandas as pd
# Hitung median data testing
median_test1 = X_test1.median()
median_test2 = X_test2.median()
median_test3 = X_test3.median()
median_test4 = X_test4.median()
median_test5 = X_test5.median()
median_test6 = X_test6.median()
median_test7 = X_test7.median()
median_test8 = X_test8.median()
median_test9 = X_test9.median()
median_test10 = X_test10.median()
median_test11 = X_test11.median()

print("Median:", median_test1)
# Out:
# Median: wmc    -0.352292
# dit    -0.301753
# noc    -0.324729
# cbo    -0.139121
# rfc    -0.221794
# lcom   -0.312078
# dtype: float64

# %%
import numpy as np

# membuat daftar label untuk kolom
columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

# mendefinisikan data median
data1 = median_train1
data2 = median_train2
data3 = median_train3
data4 = median_train4
data5 = median_train5
data6 = median_train6
data7 = median_train7
data8 = median_train8
data9 = median_train9
data10 = median_train10
data11 = median_train11

# membuat dictionary dengan fungsi zip()
X1 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data1, [2] * len(data1))))
X2 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data2, [2] * len(data2))))
X3 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data3, [2] * len(data3))))
X4 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data4, [2] * len(data4))))
X5 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data5, [2] * len(data5))))
X6 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data6, [2] * len(data6))))
X7 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data7, [2] * len(data7))))
X8 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data8, [2] * len(data8))))
X9 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data9, [2] * len(data9))))
X10 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data10, [2] * len(data10))))
X11 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data11, [2] * len(data11))))

print(X1)
print(X2)
print(X3)
print(X4)
print(X5)
print(X6)
print(X7)
print(X8)
print(X9)
print(X10)
print(X11)
# Out:
# {'mean wmc': -0.34, 'mean dit': 0.33, 'mean noc': -0.16, 'mean cbo': -0.23, 'mean rfc': -0.32, 'mean lcom': -0.23}
# {'mean wmc': -0.31, 'mean dit': 0.01, 'mean noc': -0.21, 'mean cbo': -0.18, 'mean rfc': -0.29, 'mean lcom': -0.14}
# {'mean wmc': -0.34, 'mean dit': -0.63, 'mean noc': -0.26, 'mean cbo': -0.31, 'mean rfc': -0.31, 'mean lcom': -0.17}
# {'mean wmc': -0.24, 'mean dit': -0.7, 'mean noc': -0.18, 'mean cbo': -0.22, 'mean rfc': -0.27, 'mean lcom': -0.12}
# {'mean wmc': -0.24, 'mean dit': -0.62, 'mean noc': -0.23, 'mean cbo': -0.29, 'mean rfc': -0.27, 'mean lcom': -0.14}
# {'mean wmc': -0.24, 'mean dit': 0.18, 'mean noc': -0.35, 'mean cbo': -0.33, 'mean rfc': -0.22, 'mean lcom': -0.14}
# {'mean wmc': -0.23, 'mean dit': 0.18, 'mean noc': -0.11, 'mean cbo': -0.22, 'mean rfc': -0.24, 'mean lcom': -0.17}
# {'mean wmc': -0.4, 'mean dit': -0.83, 'mean noc': -0.2, 'mean cbo': -0.22, 'mean rfc': -0.25, 'mean lcom': -0.23}
# ...

# %%
import numpy as np

# membuat daftar label untuk kolom
columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

# menggabungkan data mean dan standard deviation
data1 = median_test1
data2 = median_test2
data3 = median_test3
data4 = median_test4
data5 = median_test5
data6 = median_test6
data7 = median_test7
data8 = median_test8
data9 = median_test9
data10 = median_test10
data11 = median_test11

# membuat dictionary dengan fungsi zip()
X_test1 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data1, [2] * len(data1))))
X_test2 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data2, [2] * len(data2))))
X_test3 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data3, [2] * len(data3))))
X_test4 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data4, [2] * len(data4))))
X_test5 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data5, [2] * len(data5))))
X_test6 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data6, [2] * len(data6))))
X_test7 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data7, [2] * len(data7))))
X_test8 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data8, [2] * len(data8))))
X_test9 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data9, [2] * len(data9))))
X_test10 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data10, [2] * len(data10))))
X_test11 = dict(zip(['mean ' + c for c in columns] + ['std ' + c for c in columns], map(round, data11, [2] * len(data11))))

print(X_test1)
print(X_test2)
print(X_test3)
print(X_test4)
print(X_test5)
print(X_test6)
print(X_test7)
print(X_test8)
print(X_test9)
print(X_test10)
print(X_test11)
# Out:
# {'mean wmc': -0.35, 'mean dit': -0.3, 'mean noc': -0.32, 'mean cbo': -0.14, 'mean rfc': -0.22, 'mean lcom': -0.31}
# {'mean wmc': -0.38, 'mean dit': -0.67, 'mean noc': -0.16, 'mean cbo': -0.21, 'mean rfc': -0.27, 'mean lcom': -0.3}
# {'mean wmc': -0.33, 'mean dit': -0.69, 'mean noc': -0.4, 'mean cbo': -0.34, 'mean rfc': -0.4, 'mean lcom': -0.28}
# {'mean wmc': -0.3, 'mean dit': -0.18, 'mean noc': -0.27, 'mean cbo': -0.25, 'mean rfc': -0.26, 'mean lcom': -0.25}
# {'mean wmc': -0.36, 'mean dit': -0.68, 'mean noc': -0.31, 'mean cbo': -0.32, 'mean rfc': -0.13, 'mean lcom': -0.54}
# {'mean wmc': -0.32, 'mean dit': -0.23, 'mean noc': -0.47, 'mean cbo': -0.21, 'mean rfc': -0.28, 'mean lcom': -0.21}
# {'mean wmc': -0.29, 'mean dit': 0.04, 'mean noc': -0.31, 'mean cbo': -0.31, 'mean rfc': -0.32, 'mean lcom': -0.27}
# {'mean wmc': -0.31, 'mean dit': -0.78, 'mean noc': -0.16, 'mean cbo': -0.22, 'mean rfc': -0.23, 'mean lcom': -0.22}
# ...

# %% [markdown]
# ant

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X2, X3, X4, X5, X6, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test1

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X2  0.381051
# 1      X3  0.411339
# 2      X4  0.486518
# 3      X5  0.420119
# 4      X6  0.555338
# 5      X7  0.561516
# 6      X8  0.558122
# 7      X9  0.524881
# 8     X10  0.687459
# 9     X11  0.518845
#   project  distance
# 0      X2  0.381051
# 1      X3  0.411339
# 3      X5  0.420119

# %% [markdown]
# camel

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X3, X4, X5, X6, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test2

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  1.004689
# 1      X3  0.204206
# 2      X4  0.231084
# 3      X5  0.242899
# 4      X6  0.905925
# 5      X7  0.874871
# 6      X8  0.181659
# 7      X9  0.219089
# 8     X10  1.017399
# 9     X11  0.159687
#   project  distance
# 9     X11  0.159687
# 6      X8  0.181659
# 1      X3  0.204206

# %% [markdown]
# ivy

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X4, X5, X6, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test3

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  1.057875
# 1      X2  0.764068
# 2      X4  0.336898
# 3      X5  0.284429
# 4      X6  0.905318
# 5      X7  0.950316
# 6      X8  0.322335
# 7      X9  0.289310
# 8     X10  1.039134
# 9     X11  0.287750
#   project  distance
# 3      X5  0.284429
# 9     X11  0.287750
# 7      X9  0.289310

# %% [markdown]
# jedit

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X5, X6, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test4

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  0.527447
# 1      X2  0.240208
# 2      X3  0.465510
# 3      X5  0.461086
# 4      X6  0.399625
# 5      X7  0.409634
# 6      X8  0.662420
# 7      X9  0.575152
# 8     X10  0.532071
# 9     X11  0.585747
#   project  distance
# 1      X2  0.240208
# 4      X6  0.399625
# 5      X7  0.409634

# %% [markdown]
# log4j

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X6, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test5

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  1.087796
# 1      X2  0.832947
# 2      X3  0.418091
# 3      X4  0.487545
# 4      X6  0.961145
# 5      X7  0.977497
# 6      X8  0.395854
# 7      X9  0.472758
# 8     X10  1.090963
# 9     X11  0.327719
#   project  distance
# 9     X11  0.327719
# 6      X8  0.395854
# 2      X3  0.418091

# %% [markdown]
# lucene

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X7, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test6

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X5', 'X7', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  0.642262
# 1      X2  0.362215
# 2      X3  0.465833
# 3      X4  0.565420
# 4      X5  0.476970
# 5      X7  0.555968
# 6      X8  0.663852
# 7      X9  0.596238
# 8     X10  0.630714
# 9     X11  0.625460
#   project  distance
# 1      X2  0.362215
# 2      X3  0.465833
# 4      X5  0.476970

# %% [markdown]
# poi

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X6, X8, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test7

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1','X2', 'X3', 'X4', 'X5', 'X6', 'X8', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  0.342199
# 1      X2  0.214476
# 2      X3  0.681175
# 3      X4  0.774661
# 4      X5  0.681396
# 5      X6  0.225832
# 6      X8  0.892020
# 7      X9  0.793410
# 8     X10  0.318434
# 9     X11  0.801623
#   project  distance
# 1      X2  0.214476
# 5      X6  0.225832
# 8     X10  0.318434

# %% [markdown]
# synapse

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X6, X7, X9, X10, X11])

# mendefinisikan projek target Y
Y = X_test8

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X9', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  1.114136
# 1      X2  0.798874
# 2      X3  0.224499
# 3      X4  0.152643
# 4      X5  0.219773
# 5      X6  0.990555
# 6      X7  0.965971
# 7      X9  0.154596
# 8     X10  1.125344
# 9     X11  0.167929
#   project  distance
# 3      X4  0.152643
# 7      X9  0.154596
# 9     X11  0.167929

# %% [markdown]
# velocity

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X6, X7, X8, X10, X11])

# mendefinisikan projek target Y
Y = X_test9

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X10', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  0.240624
# 1      X2  0.555518
# 2      X3  1.187687
# 3      X4  1.257418
# 4      X5  1.176563
# 5      X6  0.423320
# 6      X7  0.393065
# 7      X8  1.384738
# 8     X10  0.267955
# 9     X11  1.297767
#   project  distance
# 0      X1  0.240624
# 8     X10  0.267955
# 6      X7  0.393065

# %% [markdown]
# xalan

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X6, X7, X8, X9, X11])

# mendefinisikan projek target Y
Y = X_test10

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X11'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  0.666183
# 1      X2  0.370810
# 2      X3  0.312890
# 3      X4  0.399750
# 4      X5  0.312410
# 5      X6  0.550908
# 6      X7  0.537029
# 7      X8  0.520961
# 8      X9  0.409145
# 9     X11  0.429535
#   project  distance
# 4      X5   0.31241
# 2      X3   0.31289
# 1      X2   0.37081

# %% [markdown]
# xerces

# %%
# mendefinisikan projek target Y
X = pd.DataFrame.from_dict([X1, X2, X3, X4, X5, X6, X7, X8, X9, X10])

# mendefinisikan projek target Y
Y = X_test11

# menghitung Euclidean distance
distances = np.sqrt(np.sum((X - Y)**2, axis=1))

# membuat dataframe baru untuk Euclidean distance
df_distances = pd.DataFrame({'project': ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10'],
                             'distance': distances})

#menampilkan hasil Euclidean distance
print(df_distances)

#mengambil tiga proyek dengan nilai Euclidean distance terendah
closest_projects = df_distances.nsmallest(3, 'distance')

#menampilkan tiga proyek dengan nilai Euclidean distance terendah
print(closest_projects)
# Out:
#   project  distance
# 0      X1  1.187434
# 1      X2  0.899611
# 2      X3  0.294449
# 3      X4  0.352420
# 4      X5  0.336749
# 5      X6  1.043408
# 6      X7  1.063391
# 7      X8  0.266458
# 8      X9  0.288097
# 9     X10  1.175968
#   project  distance
# 7      X8  0.266458
# 8      X9  0.288097
# 2      X3  0.294449

# %% [markdown]
# ##Data

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# Split the data into training and testing sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(feature1, target1, test_size=0.2, random_state=0)
X_train2, X_test2, y_train2, y_test2 = train_test_split(feature2, target2, test_size=0.2, random_state=0)
X_train3, X_test3, y_train3, y_test3 = train_test_split(feature3, target3, test_size=0.2, random_state=0)
X_train4, X_test4, y_train4, y_test4 = train_test_split(feature4, target4, test_size=0.2, random_state=0)
X_train5, X_test5, y_train5, y_test5 = train_test_split(feature5, target5, test_size=0.2, random_state=0)
X_train6, X_test6, y_train6, y_test6 = train_test_split(feature6, target6, test_size=0.2, random_state=0)
X_train7, X_test7, y_train7, y_test7 = train_test_split(feature7, target7, test_size=0.2, random_state=0)
X_train8, X_test8, y_train8, y_test8 = train_test_split(feature8, target8, test_size=0.2, random_state=0)
X_train9, X_test9, y_train9, y_test9 = train_test_split(feature9, target9, test_size=0.2, random_state=0)
X_train10, X_test10, y_train10, y_test10 = train_test_split(feature10, target10, test_size=0.2, random_state=0)
X_train11, X_test11, y_train11, y_test11 = train_test_split(feature11, target11, test_size=0.2, random_state=0)

# %%
X_train1.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test1.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train2.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test2.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train3.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test3.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train4.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test4.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train5.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test5.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train6.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test6.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train7.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test7.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train8.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test8.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train9.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test9.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train10.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test10.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train11.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']
X_test11.columns = ['wmc', 'dit', 'noc', 'cbo', 'rfc', 'lcom']

X_train1.head(10)
# Out:
#                                                     wmc  dit  noc  cbo  rfc  \
# name
# org.apache.tools.ant.taskdefs.optional.clearcas...    5    4    0    7   27
# org.apache.tools.ant.taskdefs.optional.junit.XM...   12    3    0   11   75
# org.apache.tools.ant.taskdefs.optional.ejb.Jbos...    6    2    0    5   23
# org.apache.tools.ant.Executor                         2    1    0    4    2
# org.apache.tools.ant.taskdefs.optional.extensio...   13    3    0   10   36
# org.apache.tools.ant.types.resources.Sort             4    4    1   11   20
# org.apache.tools.ant.util.LineOrientedOutputStream    7    2    2    2   15
# org.apache.tools.ant.ProjectComponent                10    1   28   67   14
# org.apache.tools.ant.taskdefs.optional.ejb.IPla...   20    1    0    7   79
# org.apache.tools.ant.taskdefs.Copy                   45    3    2   25  157
#
#                                                     lcom
# name
# org.apache.tools.ant.taskdefs.optional.clearcas...     4
# ...

# %% [markdown]
# ##Ant

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
import numpy as np

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train2, X_train3, X_train5], axis=0)
y_train = pd.concat([y_train2, y_train3, y_train5], axis=0)
X_test = X_test1
y_test = y_test1

X_test.head()
# Out:
#                                                          wmc       dit  \
# name
# org.apache.tools.ant.taskdefs.Chmod                 0.726973  1.711434
# org.apache.tools.ant.types.ResourceLocation        -0.352292 -0.972815
# org.apache.tools.ant.taskdefs.optional.clearcas...  0.825088  1.040372
# org.apache.tools.ant.taskdefs.DefBase               0.334513  1.040372
# org.apache.tools.ant.types.resources.selectors.Or  -0.744752  1.040372
#
#                                                          noc       cbo  \
# name
# org.apache.tools.ant.taskdefs.Chmod                -0.324729 -0.045005
# org.apache.tools.ant.types.ResourceLocation         0.623989 -0.162650
# org.apache.tools.ant.taskdefs.optional.clearcas... -0.324729 -0.139121
# org.apache.tools.ant.taskdefs.DefBase               2.521424 -0.045005
# org.apache.tools.ant.types.resources.selectors.Or  -0.324729 -0.209708
#
#                                                          rfc      lcom
# name
# ...

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1217, 6)
# (1217,)
# (149, 6)
# (149,)

# %%
import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())
# Out:
# 0    883
# 1    334
# Name: bug, dtype: int64

# %%
# Initialize SMOTE
sm = SMOTE(random_state=0)

# %%
# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())
# Out:
# 0    883
# 1    883
# Name: bug, dtype: int64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 10s 7ms/step - loss: 0.6967 - accuracy: 0.5527
# Epoch 2/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6934 - accuracy: 0.5521
# Epoch 3/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5442
# Epoch 4/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.6691 - accuracy: 0.5821
# Epoch 5/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6802 - accuracy: 0.5883
# Epoch 6/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6763 - accuracy: 0.5764
# Epoch 7/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.6751 - accuracy: 0.5849
# Epoch 8/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.6728 - accuracy: 0.5895
# Epoch 9/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.6729 - accuracy: 0.5951
# Epoch 10/100
# ...

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5219 - accuracy: 0.7919

# %%
# Print the accuracy
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.791946291923523

# %%
# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))
# Out:
# 5/5 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87       117
#            1       0.51      0.56      0.54        32
#
#     accuracy                           0.79       149
#    macro avg       0.70      0.71      0.70       149
# weighted avg       0.80      0.79      0.80       149

# %%
# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)
# Out:
# Confusion Matrix:
# [[100  17]
#  [ 14  18]]

# %%
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)
# Out:
# 5/5 [==============================] - 0s 2ms/step
# F1 score: 0.5373134328358209
# AUC: 0.7086004273504273
# Precision:  0.5142857142857142
# Recall:  0.5625

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(120.72222222222221, 0.5, 'True')

# %%
# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##Camel

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train11, X_train8, X_train3], axis=0)
y_train = pd.concat([y_train11, y_train8, y_train3], axis=0)
X_test = X_test2
y_test = y_test2

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())
# Out:
# 0    511
# 1    444
# Name: bug, dtype: int64
# 1    511
# 0    511
# Name: bug, dtype: int64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 64)                448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 0.6912 - accuracy: 0.5519
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6827 - accuracy: 0.5841
# Epoch 3/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.6360
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6421 - accuracy: 0.6673
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.6370
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6401 - accuracy: 0.6654
# Epoch 7/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6229 - accuracy: 0.6624
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6338 - accuracy: 0.6781
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6139 - accuracy: 0.6840
# Epoch 10/100
# ...

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0083 - accuracy: 0.3627
# Accuracy: 0.36269429326057434

# %%
# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.25      0.39       158
#            1       0.21      0.89      0.34        35
#
#     accuracy                           0.36       193
#    macro avg       0.56      0.57      0.36       193
# weighted avg       0.78      0.36      0.38       193

# %%
# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)
# Out:
# Confusion Matrix:
# [[ 39 119]
#  [  4  31]]

# %%
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)
# Out:
# 7/7 [==============================] - 0s 2ms/step
# F1 score: 0.33513513513513515
# AUC: 0.5662748643761302
# Precision:  0.20666666666666667
# Recall:  0.8857142857142857

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##Ivy

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train5, X_train11, X_train9], axis=0)
y_train = pd.concat([y_train5, y_train11, y_train9], axis=0)
X_test = X_test3
y_test = y_test3

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1    562
# 0    255
# Name: bug, dtype: int64
# 1    562
# 0    562
# Name: bug, dtype: int64
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 64)                448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 5ms/step - loss: 0.6802 - accuracy: 0.5525
# Epoch 2/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6626 - accuracy: 0.6032
# Epoch 3/100
# ...

# %% [markdown]
# ##Jedit

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train2, X_train6, X_train7], axis=0)
y_train = pd.concat([y_train2, y_train6, y_train7], axis=0)
X_test = X_test4
y_test = y_test4

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    856
# 1    541
# Name: bug, dtype: int64
# 0    856
# 1    856
# Name: bug, dtype: int64
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 64)                448
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 [==============================] - 1s 3ms/step - loss: 0.7053 - accuracy: 0.5409
# Epoch 2/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.5765
# Epoch 3/100
# ...

# %% [markdown]
# ##Log4j

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train11, X_train8, X_train3], axis=0)
y_train = pd.concat([y_train11, y_train8, y_train3], axis=0)
X_test = X_test5
y_test = y_test5

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    511
# 1    444
# Name: bug, dtype: int64
# 1    511
# 0    511
# Name: bug, dtype: int64
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 64)                448
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 0.7066 - accuracy: 0.5450
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6758 - accuracy: 0.5783
# Epoch 3/100
# ...

# %% [markdown]
# ##Lucene

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train2, X_train3, X_train5], axis=0)
y_train = pd.concat([y_train2, y_train3, y_train5], axis=0)
X_test = X_test6
y_test = y_test6

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    883
# 1    334
# Name: bug, dtype: int64
# 0    883
# 1    883
# Name: bug, dtype: int64
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 64)                448
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 56/56 [==============================] - 1s 3ms/step - loss: 0.7066 - accuracy: 0.5153
# Epoch 2/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.6962 - accuracy: 0.5362
# Epoch 3/100
# ...

# %% [markdown]
# ##poi

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train2, X_train6, X_train10], axis=0)
y_train = pd.concat([y_train2, y_train6, y_train10], axis=0)
X_test = X_test7
y_test = y_test7

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1    1034
# 0     737
# Name: bug, dtype: int64
# 0    1034
# 1    1034
# Name: bug, dtype: int64
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 64)                448
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 65/65 [==============================] - 1s 3ms/step - loss: 0.7029 - accuracy: 0.5179
# Epoch 2/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.5426
# Epoch 3/100
# ...

# %% [markdown]
# ##synapse

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train4, X_train9, X_train11], axis=0)
y_train = pd.concat([y_train4, y_train9, y_train11], axis=0)
X_test = X_test8
y_test = y_test8

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    625
# 1    421
# Name: bug, dtype: int64
# 0    625
# 1    625
# Name: bug, dtype: int64
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 64)                448
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_23 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 40/40 [==============================] - 1s 4ms/step - loss: 0.7371 - accuracy: 0.5272
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.5648
# Epoch 3/100
# ...

# %% [markdown]
# ##velocity

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train1, X_train10, X_train7], axis=0)
y_train = pd.concat([y_train1, y_train10, y_train7], axis=0)
X_test = X_test9
y_test = y_test9

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1    1077
# 0     599
# Name: bug, dtype: int64
# 0    1077
# 1    1077
# Name: bug, dtype: int64
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 64)                448
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dropout_17 (Dropout)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 68/68 [==============================] - 1s 4ms/step - loss: 0.6905 - accuracy: 0.5557
# Epoch 2/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6705 - accuracy: 0.5989
# Epoch 3/100
# ...

# %% [markdown]
# ##Xalan

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train5, X_train3, X_train2], axis=0)
y_train = pd.concat([y_train5, y_train3, y_train2], axis=0)
X_test = X_test10
y_test = y_test10

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    883
# 1    334
# Name: bug, dtype: int64
# 1    883
# 0    883
# Name: bug, dtype: int64
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 64)                448
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_29 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 56/56 [==============================] - 2s 3ms/step - loss: 0.7183 - accuracy: 0.5113
# Epoch 2/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.7088 - accuracy: 0.5159
# Epoch 3/100
# ...

# %% [markdown]
# ##Xerces

# %%
# Concatenate features and target from all datasets
X_train = pd.concat([X_train8, X_train9, X_train3], axis=0)
y_train = pd.concat([y_train8, y_train9, y_train3], axis=0)
X_test = X_test11
y_test = y_test11

X_test.head()

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

# Initialize SMOTE
sm = SMOTE(random_state=0)

# Fit and resample the minority class
X_train, y_train = sm.fit_resample(X_train, y_train)

import matplotlib.pyplot as plt

counts = y_train.value_counts()
plt.bar(counts.index, counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

print(y_train.value_counts())

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Create the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print('Accuracy:', accuracy)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(classification_report(y_test, y_pred))

# Create a confusion matrix
cm = confusion_matrix
#Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
#Print the confusion matrix
print('Confusion Matrix:')
print(cm)

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

#calculating precision and reall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the score
print('F1 score:', f1)
print('AUC:', auc)
print('Precision: ',precision)
print('Recall: ',recall)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0    507
# 1    161
# Name: bug, dtype: int64
# 0    507
# 1    507
# Name: bug, dtype: int64
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 64)                448
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_31 (Dense)            (None, 32)                2080
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_32 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 1s 4ms/step - loss: 0.7043 - accuracy: 0.5848
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6406 - accuracy: 0.6430
# Epoch 3/100
# ...
